# %%
import pandas as pd
import matplotlib.pyplot as plt
colnames=['id', 'fv1', 'fv2', 'fv3','fv4','fv5','fv6','fv7','fv8','fv9','cl']
df = pd.read_csv('breast-cancer-wisconsin.csv', names=colnames, header=None)
print(df.head())
# Out:
#         id  fv1  fv2  fv3  fv4  fv5 fv6  fv7  fv8  fv9  cl
# 0  1000025    5    1    1    1    2   1    3    1    1   2
# 1  1002945    5    4    4    5    7  10    3    2    1   2
# 2  1015425    3    1    1    1    2   2    3    1    1   2
# 3  1016277    6    8    8    1    3   4    3    7    1   2
# 4  1017023    4    1    1    3    2   1    3    1    1   2

# %%
for i in range(1,10):
    plt.hist(df_2['fv'+str(i)],label='cl=2',alpha=0.5,bins=6,color='green')
    plt.hist(df_4['fv'+str(i)],label='cl=4',alpha=0.5,bins=6,color='red')
    plt.legend()
    plt.title(i)
    plt.show()

# %%
def histogram_intersection(j):
    sm = 0
    f='fv'+str(j)
    for i in range(1,11):
        sm += min(len(df_2[df_2[f] == i]), len(df_4[f] == i))
    print("feature"+j+": "+str(sm))

for i in range(1,10):
    histogram_intersection(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-562428532e92> in <module>
#       7
#       8 for i in range(1,10):
# ----> 9     histogram_intersection(i)
#
# <ipython-input-60-562428532e92> in histogram_intersection(j)
#       4     for i in range(1,11):
#       5         sm += min(len(df_2[df_2[f] == i]), len(df_4[f] == i))
# ----> 6     print("feature"+j+": "+str(sm))
#       7
#       8 for i in range(1,10):
#
# TypeError: can only concatenate str (not "int") to str
